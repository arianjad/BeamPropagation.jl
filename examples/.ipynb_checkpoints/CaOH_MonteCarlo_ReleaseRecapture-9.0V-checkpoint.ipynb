# %% [markdown]
# ### Monte Carlo Release-Recapture Temperatures

# %%
using BeamPropagation, 
    Distributions, 
    UnitsToValue,
    StatsBase, 
    StaticArrays, 
    Plots,
    StructArrays,
    MutableNamedTuples,
    PhysicalConstants.CODATA2018,
    LinearAlgebra

# %%
# Define physical constants
const kB = BoltzmannConstant.val
const T = @with_unit 30 "μK"

# Define molecule parameters for CaOH
const m = @with_unit 57 "u"
const v_recoil = @with_unit 1.1 "cm/s"
;

# %%
# Define tweezer beam properties
const T_depth = @with_unit 1.4 "mK"
const U_max = kB * T_depth
const λ = 780e-9
const w0x = 2.0e-6
const w0y = 2.0e-6

# Create an instance of a gaussian trap for the tweezer
trap = AsymmetricGaussianTrap(λ=λ, w0x=w0x, w0y=w0y, U_max=U_max, m=m)
;

# %%
total_time = @with_unit 5000 "μs"               
release_start_time = @with_unit 2000 "μs"        
release_end_time = @with_unit 2020 "μs"         
;

# %%
n = 5000
save_every = 10
delete_every = 50
dt_min = 1e-10
dt_max = 1e-4
abstol = 1e-5
dt = 1e-7
max_steps = Int64(ceil(total_time / dt))
alg = "rkf12"
use_adaptive = false
dt0 = 1e-5
times = (0:dt:max_steps * dt)[1:save_every:end-1]
;

# %%
discard(r, v) = false
is_detectable(r, trap) = (abs(r[1]) < 5trap.w0x) && (abs(r[2]) < 5trap.w0y) && (abs(r[3]) < 5max(trap.zRx, trap.zRy))

function update(particles, p, s, dt, time, idx)
    for i in 1:size(particles, 1)
        idx = particles.idx[i]
        r = particles.r[i]
        s.detectable[idx] = is_detectable(r, p.trap)
    end
    return nothing
end

gravity(r) = SVector(0.0, -9.81, 0.0)

function f(idx, r, v, p, time)
    if p.release_start_time < time < p.release_end_time
        U_depth = 0.0
    else
        U_depth = p.trap.U_max
    end
    return F(r, p.trap) * U_depth / m + gravity(r)
end

function save(particles, p, s)
    for i in 1:size(particles, 1)
        idx = particles.idx[i]
        push!(s.trajectories[idx], particles.r[i])
    end
    return nothing
end
;

# %%
detectable = zeros(Bool, n)

particles = StructArray{Particle}(undef, n)
trajectories = [SVector{3, Float64}[] for _ ∈ 1:length(particles)]

r, v, a = make_distributions(T, trap)

p = @params (trap, release_start_time, release_end_time)
s = @params (detectable, trajectories)

@time propagate_particles!(r, v, a, 
    alg, particles, f, save, discard, save_every, delete_every, max_steps, update, p, s, dt, use_adaptive, 
    dt_min, dt_max, abstol, true
)
mean(s.detectable) |> display
# Out:
#   5.551992 seconds (151.16 k allocations: 1.748 GiB, 2.61% gc time, 31.49% compilation time: 10% of which was recompilation)
# 0.8338

# %%
survival = vec(mean(mapreduce(permutedims, vcat, [[is_detectable(s.trajectories[i][j], trap) for j ∈ 1:length(times)] for i ∈ 1:n]), dims=1))
plot(times, survival, legend=nothing)
plot!(ylim=(0,1))
vline!([release_start_time, release_end_time])

# %%
x_trajectories = [x[1] for x ∈ s.trajectories[7]]
y_trajectories = [x[2] for x ∈ s.trajectories[7]]
z_trajectories = [x[3] for x ∈ s.trajectories[7]]
;

# %%
plot(x_trajectories, y_trajectories, z_trajectories)

# %% [markdown]
# ## Scan in-trap temperature to fit to data

# %%
data_xs = 1e-6 .* [
    2
    4
    6
    8
    10
    12
    14
    20
    24
    30
    35
    40
    50
]

data_ys = [
    0.641509433962264
    0.609154929577465
    0.50390625
    0.439114391143911
    0.38728323699422
    0.351063829787234
    0.26865671641791
    0.212121212121212
    0.210526315789474
    0.152046783625731
    0.142105263157895
    0.0679012345679012
    0.0552147239263804
]
;

# %%
scatter(data_xs, data_ys)

# %%
# Create a release-recapture plot for a single temperature
const T = T_depth / 10;
r, v, a = make_distributions(T, trap)
release_durations = deepcopy(data_xs)

surviving_fractions = zeros(length(release_durations))
for (i, release_duration) ∈ enumerate(release_durations)

    # Reset parameters for current run
    p.release_start_time = release_start_time
    p.release_end_time = release_start_time + release_duration
    
    particles = StructArray{Particle}(undef, n)
    detectable = zeros(Bool, n)
    trajectories = [SVector{3, Float64}[] for _ ∈ 1:length(particles)]
    s = @params (detectable, trajectories)

    @time propagate_particles!(r, v, a, alg, particles, f, save, discard, save_every, delete_every, max_steps, update, p, s, dt, use_adaptive, 
        dt_min, dt_max, abstol, true)

    surviving_fractions[i] = mean(s.detectable)
end
# Out:
# WARNING: redefinition of constant T. This may fail, cause incorrect answers, or produce other errors.
#   3.872772 seconds (28.24 k allocations: 109.154 MiB)
#   3.833091 seconds (20.52 k allocations: 108.703 MiB)
#   3.961719 seconds (20.52 k allocations: 108.703 MiB)
#   3.976974 seconds (20.53 k allocations: 108.703 MiB)
#   5.857477 seconds (20.55 k allocations: 108.703 MiB, 5.45% gc time)
#   3.705271 seconds (20.64 k allocations: 108.713 MiB)
#   3.917923 seconds (20.53 k allocations: 108.703 MiB)
#   4.110750 seconds (20.53 k allocations: 108.703 MiB)
#   4.233267 seconds (20.53 k allocations: 108.703 MiB)
#   4.098279 seconds (20.53 k allocations: 108.703 MiB)
#   4.189972 seconds (20.64 k allocations: 108.713 MiB)
#   6.157817 seconds (20.54 k allocations: 108.703 MiB, 21.92% gc time)
#   4.298955 seconds (20.53 k allocations: 108.703 MiB)

# %%
plot(release_durations .* 1e6, 0.62 * surviving_fractions,
    title="Release-recapture after Λ-imaging",
    linewidth=3,
    box=:on,
    label="Monte Carlo simulation",
    xlabel="Release duration (μs)",
    ylabel="Fraction remaining"
)
scatter!(data_xs  .* 1e6, data_ys, label="Data")

# %%
ηs = 5:0.5:13
Ts = T_depth ./ ηs

release_durations = data_xs
surviving_fractions = Vector{Float64}[]

iter = Ts
for (i, T) ∈ enumerate(Ts)
    display(ηs[i])
    r, v, a = make_distributions(T, trap)
    surviving_fraction = zeros(length(release_durations))

    for (j, release_duration) ∈ enumerate(release_durations)

        # Reset parameters for current run
        p.release_start_time = release_start_time
        p.release_end_time = release_start_time + release_duration

        particles = StructArray{Particle}(undef, n)
        detectable = zeros(Bool, n)
        trajectories = [SVector{3, Float64}[] for _ ∈ 1:length(particles)]
        s = @params (detectable, trajectories)

        @time propagate_particles!(r, v, a, alg, particles, f, save, discard, save_every, delete_every, max_steps, update, p, s, dt, use_adaptive, 
            dt_min, dt_max, abstol, true)

        surviving_fraction[j] = mean(s.detectable)
        
    end
    push!(surviving_fractions, surviving_fraction) 
end
# Out:
# 5.0
#   3.810721 seconds (20.40 k allocations: 108.692 MiB)
#   3.819649 seconds (20.64 k allocations: 108.713 MiB)
#   4.024077 seconds (20.64 k allocations: 108.713 MiB)
#   3.991426 seconds (20.53 k allocations: 108.703 MiB)
#   6.036807 seconds (20.66 k allocations: 108.713 MiB, 6.88% gc time)
#   3.808986 seconds (20.53 k allocations: 108.703 MiB)
#   3.969788 seconds (20.53 k allocations: 108.703 MiB)
#   4.110789 seconds (20.52 k allocations: 108.703 MiB)
#   4.225494 seconds (20.54 k allocations: 108.703 MiB)
#   4.299272 seconds (20.52 k allocations: 108.703 MiB)
#   6.431578 seconds (20.55 k allocations: 108.703 MiB, 7.76% gc time)
#   4.098959 seconds (20.52 k allocations: 108.703 MiB)
#   4.154889 seconds (20.53 k allocations: 108.703 MiB)
# 5.5
#   3.959449 seconds (20.41 k allocations: 108.693 MiB)
#   3.854192 seconds (20.52 k allocations: 108.703 MiB)
#   3.942036 seconds (20.52 k allocations: 108.703 MiB)
#   4.016476 seconds (20.52 k allocations: 108.703 MiB)
#   4.490371 seconds (20.52 k allocations: 108.703 MiB, 13.30% gc time)
#   4.223959 seconds (20.52 k allocations: 108.702 MiB)
#   3.920532 seconds (20.52 k allocations: 108.703 MiB)
#   4.209291 seconds (20.65 k allocations: 108.713 MiB)
#   4.064491 seconds (20.52 k allocations: 108.703 MiB)
#   4.166095 seconds (20.52 k allocations: 108.703 MiB)
#   6.283862 seconds (20.54 k allocations: 108.703 MiB, 6.82% gc time)
#   4.290027 seconds (20.65 k allocations: 108.713 MiB)
#   4.078032 seconds (20.52 k allocations: 108.703 MiB)
# 6.0
#   3.991946 seconds (20.40 k allocations: 108.692 MiB)
#   3.869042 seconds (20.52 k allocations: 108.703 MiB)
#   3.872951 seconds (20.52 k allocations: 108.703 MiB)
#   4.042429 seconds (20.52 k allocations: 108.703 MiB)
#   3.954979 seconds (20.52 k allocations: 108.703 MiB)
#   3.930118 seconds (20.52 k allocations: 108.703 MiB)
#   3.976181 seconds (20.52 k allocations: 108.703 MiB)
#   4.003783 seconds (20.52 k allocations: 108.703 MiB)
#   4.232443 seconds (20.53 k allocations: 108.703 MiB)
#   4.011694 seconds (20.52 k allocations: 108.703 MiB)
#   6.417985 seconds (20.56 k allocations: 108.703 MiB, 7.15% gc time)
#   4.190517 seconds (20.52 k allocations: 108.703 MiB)
#   4.094183 seconds (20.52 k allocations: 108.703 MiB)
# 6.5
#   3.586481 seconds (20.39 k allocations: 108.692 MiB)
#   3.708369 seconds (20.52 k allocations: 108.703 MiB)
#   3.866517 seconds (20.64 k allocations: 108.713 MiB)
#   6.735155 seconds (20.54 k allocations: 108.703 MiB, 16.16% gc time)
#   4.025395 seconds (20.53 k allocations: 108.703 MiB)
#   3.985900 seconds (20.52 k allocations: 108.703 MiB)
#   3.874734 seconds (20.52 k allocations: 108.703 MiB)
#   4.102884 seconds (20.65 k allocations: 108.713 MiB)
#   3.965851 seconds (20.64 k allocations: 108.712 MiB)
#   3.916100 seconds (20.52 k allocations: 108.703 MiB)
#   5.341621 seconds (20.53 k allocations: 108.703 MiB, 11.16% gc time)
#   4.078299 seconds (20.52 k allocations: 108.703 MiB)
#   4.071329 seconds (20.51 k allocations: 108.703 MiB)
# 7.0
#   3.789061 seconds (20.40 k allocations: 108.693 MiB)
#   4.061388 seconds (20.52 k allocations: 108.703 MiB)
#   3.815244 seconds (20.52 k allocations: 108.703 MiB)
#   6.169778 seconds (20.55 k allocations: 108.703 MiB, 8.14% gc time)
#   4.004705 seconds (20.65 k allocations: 108.713 MiB)
#   4.016852 seconds (20.64 k allocations: 108.712 MiB)
#   4.084691 seconds (20.53 k allocations: 108.703 MiB)
#   4.056665 seconds (20.52 k allocations: 108.703 MiB)
#   4.142766 seconds (20.53 k allocations: 108.703 MiB)
#   6.697874 seconds (20.55 k allocations: 108.703 MiB, 9.31% gc time)
#   4.096381 seconds (20.52 k allocations: 108.703 MiB)
#   4.063171 seconds (20.52 k allocations: 108.703 MiB)
#   4.135303 seconds (20.52 k allocations: 108.703 MiB)
# 7.5
#   4.008026 seconds (20.40 k allocations: 108.692 MiB)
#   3.831347 seconds (20.52 k allocations: 108.702 MiB)
#   3.896307 seconds (20.52 k allocations: 108.703 MiB)
#   5.375409 seconds (20.54 k allocations: 108.703 MiB, 13.62% gc time)
#   4.089715 seconds (20.53 k allocations: 108.703 MiB)
#   4.059357 seconds (20.52 k allocations: 108.703 MiB)
#   3.878861 seconds (20.52 k allocations: 108.703 MiB)
#   4.046216 seconds (20.64 k allocations: 108.713 MiB)
#   3.894305 seconds (20.52 k allocations: 108.703 MiB)
#   6.501039 seconds (20.67 k allocations: 108.713 MiB, 7.76% gc time)
#   3.939784 seconds (20.52 k allocations: 108.703 MiB)
#   4.160630 seconds (20.53 k allocations: 108.703 MiB)
#   4.147845 seconds (20.64 k allocations: 108.713 MiB)
# 8.0
#   4.023875 seconds (20.40 k allocations: 108.692 MiB)
#   4.074270 seconds (20.52 k allocations: 108.703 MiB)
#   3.939294 seconds (20.52 k allocations: 108.703 MiB)
#   3.979242 seconds (20.52 k allocations: 108.703 MiB)
#   4.020814 seconds (20.52 k allocations: 108.703 MiB)
#   4.198499 seconds (20.52 k allocations: 108.703 MiB)
#   4.078993 seconds (20.52 k allocations: 108.703 MiB)
#   3.806372 seconds (20.51 k allocations: 108.703 MiB)
#   3.997837 seconds (20.52 k allocations: 108.703 MiB)
#   6.257551 seconds (20.68 k allocations: 108.713 MiB, 7.52% gc time)
#   4.061958 seconds (20.52 k allocations: 108.703 MiB)
#   3.959456 seconds (20.51 k allocations: 108.702 MiB)
#   4.219959 seconds (20.52 k allocations: 108.703 MiB)
# 8.5
#   3.783336 seconds (20.40 k allocations: 108.693 MiB)
#   3.706683 seconds (20.52 k allocations: 108.703 MiB)
#   6.430200 seconds (20.67 k allocations: 108.713 MiB, 11.17% gc time)
#   3.855202 seconds (20.52 k allocations: 108.703 MiB)
#   3.809526 seconds (20.64 k allocations: 108.713 MiB)
#   4.198245 seconds (20.52 k allocations: 108.703 MiB)
#   3.916980 seconds (20.52 k allocations: 108.703 MiB)
#   4.005992 seconds (20.52 k allocations: 108.703 MiB)
#   4.175984 seconds (20.52 k allocations: 108.703 MiB)
#   5.106046 seconds (20.52 k allocations: 108.703 MiB, 19.98% gc time)
#   3.914906 seconds (20.52 k allocations: 108.703 MiB)
#   4.144094 seconds (20.64 k allocations: 108.713 MiB)
#   4.090178 seconds (20.52 k allocations: 108.703 MiB)
# 9.0
#   3.750501 seconds (20.39 k allocations: 108.692 MiB)
#   3.926413 seconds (20.53 k allocations: 108.703 MiB)
#   6.023813 seconds (20.55 k allocations: 108.703 MiB, 7.40% gc time)
#   3.821780 seconds (20.51 k allocations: 108.703 MiB)
#   4.051544 seconds (20.65 k allocations: 108.713 MiB)
#   4.105050 seconds (20.52 k allocations: 108.703 MiB)
#   4.172613 seconds (20.64 k allocations: 108.713 MiB)
#   4.240311 seconds (20.65 k allocations: 108.713 MiB)
#   6.672588 seconds (20.42 k allocations: 108.693 MiB, 12.35% gc time)
#   4.164333 seconds (20.65 k allocations: 108.713 MiB)
#   4.285421 seconds (20.53 k allocations: 108.703 MiB)
#   4.213164 seconds (20.53 k allocations: 108.703 MiB)
#   3.984582 seconds (20.53 k allocations: 108.703 MiB)
# 9.5
#   3.952675 seconds (20.40 k allocations: 108.693 MiB)
#   4.037797 seconds (20.53 k allocations: 108.703 MiB)
#   4.796535 seconds (20.52 k allocations: 108.703 MiB, 9.44% gc time)
#   4.126529 seconds (20.65 k allocations: 108.713 MiB)
#   3.886756 seconds (20.52 k allocations: 108.703 MiB)
#   3.951590 seconds (20.52 k allocations: 108.703 MiB)
#   4.199079 seconds (20.53 k allocations: 108.703 MiB)
#   4.105340 seconds (20.52 k allocations: 108.703 MiB)
#   6.643717 seconds (20.55 k allocations: 108.703 MiB, 10.71% gc time)
#   4.370191 seconds (20.52 k allocations: 108.703 MiB)
#   4.455834 seconds (20.54 k allocations: 108.703 MiB)
#   4.392863 seconds (20.66 k allocations: 108.713 MiB)
# 10.0
#   4.420154 seconds (20.66 k allocations: 108.713 MiB)
#   4.102076 seconds (20.52 k allocations: 108.703 MiB)
#   6.904773 seconds (20.57 k allocations: 108.704 MiB, 5.41% gc time)
#   5.360165 seconds (20.52 k allocations: 108.703 MiB)
#   4.719670 seconds (20.52 k allocations: 108.703 MiB)
#   3.995782 seconds (20.52 k allocations: 108.703 MiB)
#   4.019493 seconds (20.52 k allocations: 108.703 MiB)
#   3.971194 seconds (20.51 k allocations: 108.703 MiB)
#   4.280367 seconds (20.52 k allocations: 108.703 MiB)
#   5.426188 seconds (20.51 k allocations: 108.702 MiB, 23.21% gc time)
#   4.044753 seconds (20.52 k allocations: 108.703 MiB)
#   4.011306 seconds (20.52 k allocations: 108.703 MiB)
#   3.998510 seconds (20.52 k allocations: 108.703 MiB)
#   4.154579 seconds (20.52 k allocations: 108.703 MiB)
# 10.5
#   3.741583 seconds (20.40 k allocations: 108.692 MiB)
#   7.014967 seconds (20.55 k allocations: 108.703 MiB, 13.18% gc time)
#   3.753665 seconds (20.52 k allocations: 108.703 MiB)
#   4.022489 seconds (20.64 k allocations: 108.713 MiB)
#   4.045860 seconds (20.53 k allocations: 108.703 MiB)
#   3.916014 seconds (20.64 k allocations: 108.713 MiB)
#   4.225405 seconds (20.52 k allocations: 108.703 MiB)
#   3.895890 seconds (20.51 k allocations: 108.703 MiB)
#   3.867260 seconds (20.52 k allocations: 108.703 MiB)
#   3.982928 seconds (20.52 k allocations: 108.703 MiB)
#   3.805101 seconds (20.51 k allocations: 108.702 MiB)
#   4.041091 seconds (20.52 k allocations: 108.703 MiB)
#   3.963820 seconds (20.52 k allocations: 108.703 MiB)
# 11.0
#   3.841416 seconds (20.40 k allocations: 108.693 MiB)
#   6.279978 seconds (20.55 k allocations: 108.704 MiB, 7.74% gc time)
#   3.757739 seconds (20.52 k allocations: 108.703 MiB)
#   3.699937 seconds (20.52 k allocations: 108.703 MiB)
#   3.945887 seconds (20.53 k allocations: 108.703 MiB)
#   3.910082 seconds (20.52 k allocations: 108.703 MiB)
#   4.002950 seconds (20.52 k allocations: 108.703 MiB)
#   4.693182 seconds (20.51 k allocations: 108.703 MiB, 13.89% gc time)
#   3.958692 seconds (20.51 k allocations: 108.703 MiB)
#   4.012652 seconds (20.52 k allocations: 108.703 MiB)
#   4.253424 seconds (20.65 k allocations: 108.713 MiB)
#   4.209517 seconds (20.53 k allocations: 108.703 MiB)
#   4.090249 seconds (20.52 k allocations: 108.703 MiB)
# 11.5
#   3.685882 seconds (20.39 k allocations: 108.692 MiB)
#   5.596709 seconds (20.66 k allocations: 108.713 MiB, 16.14% gc time)
#   3.955555 seconds (20.53 k allocations: 108.704 MiB)
#   3.921245 seconds (20.65 k allocations: 108.713 MiB)
#   4.179790 seconds (20.53 k allocations: 108.703 MiB)
#   3.915053 seconds (20.52 k allocations: 108.703 MiB)
#   3.934655 seconds (20.52 k allocations: 108.703 MiB)
#   6.600199 seconds (20.55 k allocations: 108.703 MiB, 6.88% gc time)
#   3.964060 seconds (20.52 k allocations: 108.703 MiB)
#   3.945209 seconds (20.52 k allocations: 108.703 MiB)
#   4.133454 seconds (20.53 k allocations: 108.703 MiB)
#   4.179404 seconds (20.64 k allocations: 108.713 MiB)
#   3.997004 seconds (20.53 k allocations: 108.703 MiB)
# 12.0
#   6.047612 seconds (20.43 k allocations: 108.693 MiB, 9.39% gc time)
#   3.863936 seconds (20.53 k allocations: 108.703 MiB)
#   3.847261 seconds (20.53 k allocations: 108.703 MiB)
#   3.950532 seconds (20.52 k allocations: 108.703 MiB)
#   4.034096 seconds (20.64 k allocations: 108.713 MiB)
#   3.977557 seconds (20.52 k allocations: 108.703 MiB)
#   3.886890 seconds (20.52 k allocations: 108.703 MiB)
#   5.646704 seconds (20.53 k allocations: 108.703 MiB, 15.27% gc time)
#   4.194650 seconds (20.53 k allocations: 108.703 MiB)
#   4.047147 seconds (20.52 k allocations: 108.703 MiB)
#   4.186392 seconds (20.52 k allocations: 108.703 MiB)
#   4.337573 seconds (20.52 k allocations: 108.703 MiB)
#   4.127266 seconds (20.52 k allocations: 108.703 MiB)
# 12.5
#   6.026052 seconds (20.42 k allocations: 108.693 MiB, 5.05% gc time)
#   3.790407 seconds (20.52 k allocations: 108.703 MiB)
#   3.889625 seconds (20.52 k allocations: 108.703 MiB)
#   3.871033 seconds (20.52 k allocations: 108.703 MiB)
#   3.864308 seconds (20.52 k allocations: 108.703 MiB)
#   3.870771 seconds (20.52 k allocations: 108.703 MiB)
#   3.790507 seconds (20.51 k allocations: 108.702 MiB)
#   3.935481 seconds (20.64 k allocations: 108.713 MiB)
#   4.265609 seconds (20.53 k allocations: 108.703 MiB)
#   4.093446 seconds (20.51 k allocations: 108.703 MiB)
#   4.081201 seconds (20.65 k allocations: 108.713 MiB)
#   4.160543 seconds (20.53 k allocations: 108.703 MiB)
#   4.002962 seconds (20.52 k allocations: 108.703 MiB)
# 13.0
#   4.734136 seconds (20.39 k allocations: 108.692 MiB, 14.96% gc time)
#   3.834545 seconds (20.52 k allocations: 108.703 MiB)
#   3.626614 seconds (20.52 k allocations: 108.703 MiB)
#   4.045060 seconds (20.53 k allocations: 108.703 MiB)
#   3.915838 seconds (20.52 k allocations: 108.703 MiB)
#   3.905673 seconds (20.52 k allocations: 108.703 MiB)
#   6.717265 seconds (20.55 k allocations: 108.704 MiB, 12.25% gc time)
#   3.877397 seconds (20.52 k allocations: 108.703 MiB)
#   4.259056 seconds (20.66 k allocations: 108.713 MiB)
#   4.146366 seconds (20.53 k allocations: 108.703 MiB)
#   4.010065 seconds (20.52 k allocations: 108.703 MiB)
#   4.103349 seconds (20.64 k allocations: 108.713 MiB)
#   4.036070 seconds (20.52 k allocations: 108.703 MiB)

# %%
χ²(data, preds) = sum((data .- preds).^2 ./ 0.04^2);

# %%
function model_with_best_scaling(data_ys, model_ys)
    min_error = Inf
    best_scaling = 1.0 
    for scaling ∈ 0.1:0.01:5.0
        error = χ²(data_ys, model_ys .* scaling)
        if error < min_error
            min_error = error
            best_scaling = scaling
        end
    end
    println(best_scaling)
    return model_ys .* best_scaling
end
# Out:
# model_with_best_scaling (generic function with 1 method)

# %%
χ²_errors = [
    χ²(
        data_ys,
        model_with_best_scaling(data_ys, surviving_fractions[i])
        )
    for i ∈ 1:size(surviving_fractions, 1)]
;
# Out:
# 0.78
# 0.75
# 0.71
# 0.7
# 0.68
# 0.67
# 0.65
# 0.64
# 0.63
# 0.62
# 0.61
# 0.6
# 0.59
# 0.59
# 0.58
# 0.57
# 0.56

# %%
plot(T_depth ./ Ts, χ²_errors,
    linewidth=3,
    )

# %%
# χ²_errors_1 = deepcopy(χ²_errors)
# χ²_errors_2 = deepcopy(χ²_errors)
# χ²_errors_3 = deepcopy(χ²_errors)
# χ²_errors_4 = deepcopy(χ²_errors)

# %%
plot(T_depth ./ Ts, χ²_errors_1,
    linewidth=3,
    xlabel="η",
    ylabel="χ² error",
    label="SF cooling",
    box=:on,
    title="χ² errors vs. η for release-recapture data" 
    )
plot!(T_depth ./ Ts, χ²_errors_2,
    linewidth=3,
    label="SF cooling, (100) slowing repumper off"
    )
plot!(T_depth ./ Ts, χ²_errors_3,
    linewidth=3,
    label="SF cooling, tweezer intensity PID off"
    )
plot!(T_depth ./ Ts, χ²_errors_4,
    linewidth=3,
    label="Lambda cooling"
    )
# Out:
# UndefVarError: `χ²_errors_1` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[30]:1

# %%
min_error, best_idx = findmin(χ²_errors)
Ts[best_idx] |> display
best_preds = model_with_best_scaling(data_ys, surviving_fractions[best_idx])

plot(release_durations .* 1e6, best_preds,
    title="Release-recapture after Λ-imaging",
    linewidth=3,
    box=:on,
    label="Monte Carlo simulation",
    xlabel="Release duration (μs)",
    ylabel="Fraction remaining"
)
scatter!(data_xs  .* 1e6, data_ys, label="Data")
# Out:
# 0.00014736842105263158
# 0.62

# %%
min_error, best_idx = findmin(χ²_errors)
Ts[best_idx] |> display
best_preds = model_with_best_scaling(data_ys, surviving_fractions[best_idx])

plot(release_durations .* 1e6, best_preds_75,
    title="Release-recapture after Λ-imaging",
    linewidth=3,
    box=:on,
    label="Monte Carlo simulation",
    xlabel="Release duration (μs)",
    ylabel="Fraction remaining"
)
plot!(release_durations .* 1e6, best_preds_83, linewidth=3, label="Monte Carlo simulation")
plot!(release_durations .* 1e6, best_preds_90, linewidth=3, label="Monte Carlo simulation")
scatter!(data_xs_75 .* 1e6, data_ys_75, label="Data (7.5 V detuning)")
scatter!(data_xs_83 .* 1e6, data_ys_83, label="Data (8.3 V detuning)")
scatter!(data_xs_90 .* 1e6, data_ys_90, label="Data (9.0 V detuning)")
# Out:
# 0.00014736842105263158
# 0.62
# UndefVarError: `best_preds_75` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[32]:5

# %%
data_xs_90 = deepcopy(data_xs)
data_ys_90 = deepcopy(data_ys)
best_preds_90 = deepcopy(best_preds)
;

# %%
# data_xs_75 = deepcopy(data_xs)
# data_ys_75 = deepcopy(data_ys)
# best_preds_75 = deepcopy(best_preds)
# ;

# %%
# data_xs_83 = deepcopy(data_xs)
# data_ys_83 = deepcopy(data_ys)
# best_preds_83 = deepcopy(best_preds)
# ;

# %%
min_error, best_idx = findmin(χ²_errors)
Ts[best_idx] |> display
best_preds = model_with_best_scaling(data_ys, surviving_fractions[best_idx])

plot(release_durations .* 1e6, best_preds,
    title="Release-recapture with SF cooling, \n tweezer intensity PID off \n",
    linewidth=3,
    box=:on,
    label="Monte Carlo simulation",
    xlabel="Release duration (μs)",
    ylabel="Fraction remaining"
)
scatter!(data_xs  .* 1e6, data_ys, label="Data")
# Out:
# 0.00014736842105263158
# 0.62

# %%
using LsqFit
@. model(T, p) = p[1] * (T - p[2])^2 + p[3]
# Out:
# model (generic function with 1 method)

# %%
x = 0
y = 0

lb = [0, 0.0, 0.]
p0 = [0., 8, 0.]
ub = [1.0, 20, 20.0]
fitted_model = curve_fit(model, ηs[x+1:end-y], χ²_errors[x+1:end-y], p0, lower=lb, upper=ub)
display(fitted_model.param)
plot(ηs[x+1:end-y], χ²_errors[x+1:end-y], label="Monte Carlo", xlabel="η", ylabel="χ² error")
plot!(ηs[x+1:end-y], model(ηs[x+1:end-y], fitted_model.param), label="Parabola")
# Out:
# 3-element Vector{Float64}:
#  0.4603084875540906
#  9.467493326455823
#  8.48934816041991

# %%
best_preds
# Out:
# 13-element Vector{Float64}:
#  0.616156
#  0.59024
#  0.5420039999999999
#  0.472936
#  0.407464
#  0.348688
#  0.29177200000000003
#  0.194308
#  0.153636
#  0.1085
#  0.087296
#  0.071548
#  0.051460000000000006

# %%
# The second derivative with respect to T is given by
sqrt(2 * (2fitted_model.param[1])^(-1))
# Out:
# 1.473925418677633

# %% [markdown]
# ### Bootstrap model outputs to get an error range

# %%
surviving_fractions

# %%
n = 2_000
T = 60e-6
r, v, a = make_distributions(T)

simul_xs = collect(shaved_U_depth_ratios[1]:0.01:shaved_U_depth_ratios[end])

detectable_all = zeros(n, length(simul_xs))

for (j, shaved_U_depth_ratio) ∈ enumerate(simul_xs)
    shaved_U_depth = original_U_depth * shaved_U_depth_ratio

    # Reset parameters for current run
    p.time = 0.0
    p.shaved_U_depth = shaved_U_depth

    particles = StructArray{Particle}(undef, n)
    detectable = zeros(Bool, n)
    trajectories = [SVector{3, Float64}[] for _ ∈ 1:length(particles)]
    s = @params (detectable, trajectories)

    @time propagate_particles!(r, v, a, alg, particles, f, save, discard, save_every, delete_every, max_steps, update, p, s, dt, use_adaptive, 
        dt_min, dt_max, abstol, true)

    detectable_all[:,j] .= s.detectable
    
end
# Out:
# WARNING: redefinition of constant T. This may fail, cause incorrect answers, or produce other errors.
# MethodError: no method matching make_distributions(::Float64)
#
# Closest candidates are:
#   make_distributions(::Any, ::AsymmetricGaussianTrap)
#    @ BeamPropagation C:\Google Drive\github\BeamPropagation\src\AsymmetricGaussianTrap.jl:54
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:3

# %%
n_bootstraps = 10000

surviving_fractions_lower = zeros(length(simul_xs))
surviving_fractions_upper = zeros(length(simul_xs))

for i ∈ eachindex(simul_xs)
    bootstrap_idxs = rand(1:n, n, n_bootstraps)
    bootstrap_samples = detectable_all[:,i][bootstrap_idxs]
    bootstrap_means = vec(mean(bootstrap_samples, dims=1))
    surviving_fractions_lower[i] = percentile(bootstrap_means, 50 - 34.1)
    surviving_fractions_upper[i] = percentile(bootstrap_means, 50 + 34.1)
end
# Out:
# UndefVarError: `simul_xs` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[25]:3

# %%
plot(simul_xs, surviving_fractions_lower, fillrange=surviving_fractions_upper, legend=nothing)
# Out:
# UndefVarError: `surviving_fractions_upper` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[26]:1

# %%
simul_vals = vec(mean(detectable_all, dims=1));
# Out:
# UndefVarError: `detectable_all` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[27]:1

# %%
simul_vals
# Out:
# UndefVarError: `simul_vals` not defined

# %% [markdown]
# ### Bootstrapping data

# %%
using Distributions

# %%
data_sampler(μs, ϵs) = [Normal(μs[i], ϵs[i]) for i ∈ eachindex(μs)]
ds = data_sampler(data_ys, data_ys_errors)
;
# Out:
# UndefVarError: `data_ys_errors` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[30]:2

# %%
n_bootstraps = 100_000
min_Ts = zeros(n_bootstraps)

for i ∈ 1:n_bootstraps
    bootstrap_sample = rand.(ds)
    squared_errors = vec(sum((bootstrap_sample .- surviving_fractions').^2 ./ length(data_ys), dims=1))
    _, best_idx = findmin(squared_errors)
    min_Ts[i] = Ts[best_idx]
end
histogram(min_Ts, bins=Ts)
# Out:
# UndefVarError: `ds` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ .\In[31]:5

# %%
mean(min_Ts)
# Out:
# 0.0

# %%
percentile(min_Ts, 50 - 34.1) |> display
percentile(min_Ts, 50 + 34.1) |> display
# Out:
# 0.0
# 0.0
