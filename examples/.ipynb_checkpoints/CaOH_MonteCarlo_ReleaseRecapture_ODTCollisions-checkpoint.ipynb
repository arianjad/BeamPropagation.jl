# %% [markdown]
# ### Monte Carlo Release-Recapture Temperatures

# %%
using BeamPropagation,
    Distributions, 
    UnitsToValue,
    StatsBase, 
    StaticArrays, 
    Plots,
    StructArrays,
    MutableNamedTuples,
    PhysicalConstants.CODATA2018,
    LinearAlgebra

# %%
# Define physical constants
const kB = BoltzmannConstant.val
const T = @with_unit 300 "μK"

# Define molecule parameters for CaOH
const m = @with_unit 57 "u"
const v_recoil = @with_unit 1.1 "cm/s"
;

# %%
# Define tweezer beam properties
const T_depth = @with_unit 4200 "μK"
const U_max = kB * T_depth
const λ = 1064e-9
const w0x = 9.4e-6
const w0y = 9.4e-6

# Create an instance of a gaussian trap for the tweezer
trap = AsymmetricGaussianTrap(λ=λ, w0x=w0x, w0y=w0y, U_max=U_max, m=m)
;

# %%
total_time = @with_unit 8 "ms"               
release_start_time = @with_unit 200 "μs"        
release_end_time = @with_unit 400 "μs"         
;

# %%
n = 3000
save_every = 100
delete_every = 50
dt_min = 1e-10
dt_max = 1e-4
abstol = 1e-5
dt = 1e-8
max_steps = Int64(ceil(total_time / dt))
alg = "euler"
use_adaptive = false
dt0 = 1e-5
times = (0:dt:max_steps * dt)[1:save_every:end-1]
;

# %%
using DifferentialEquations

# %%
function update(particles, p, s, dt, time, idx)
    for i in 1:size(particles, 1)
        idx = particles.idx[i]
        r = particles.r[i]
        s.detectable[idx] = is_detectable(r, p.trap)
    end
    return nothing
end

gravity(r) = SVector(0.0, -9.81, 0.0)

function f(idx, r, v, p, time)
    if p.release_start_time < time < p.release_end_time
        U_depth = p.trap.U_max * 0.0
    elseif time < p.release_start_time
        U_depth = p.trap.U_max
    elseif time > p.release_end_time
        U_depth = p.trap.U_max * (0.75 / 3.5)
    end
    return F(r, p.trap) * U_depth / m + gravity(r)
end

function save(particles, p, s)
    for i in 1:size(particles, 1)
        idx = particles.idx[i]
        push!(s.trajectories[idx], particles.r[i])
    end
    return nothing
end
;

# %%
discard(r, v) = false
is_detectable(r, trap) = (abs(r[1]) < 3trap.w0x) && (abs(r[2]) < 3trap.w0y) && (abs(r[3]) < 3max(trap.zRx, trap.zRy))

gravity(u) = SVector(0.0, -9.81, 0.0)

function update!(du, u, p, t)
    if p.release_start_time < t < p.release_end_time
        U_depth = p.trap.U_max * 0.0
    elseif t < p.release_start_time
        U_depth = p.trap.U_max
    elseif t > p.release_end_time
        U_depth = p.trap.U_max * (0.75 / 3.5)
    end
    a = F(u, p.trap) * U_depth / m + gravity(u)
    for i ∈ 1:3
        du[i] = u[i+3] # change in position
        du[i+3] = a[i] # change in velocity
    end
    return nothing
end
;

# %%
r, v, a = make_distributions(T, trap)
p = @params (trap, release_start_time, release_end_time, r, v, a)
;

# %%
# using BenchmarkTools
# u = deepcopy(u0)
# du = deepcopy(u0)
# @btime update!(du, u, p, 0.0)

# %%
u0 = [1e-6, 1e-6, 1e-6, 0, 0, 0]
tspan = (0.0, 8e-3)
prob = ODEProblem(update!, u0, tspan, p, alg=DP5(), reltol=1e-7, saveat=0.01e-3)
@time sol = solve(prob)
;
# Out:
#   0.266951 seconds (166.43 k allocations: 11.456 MiB, 99.47% compilation time: 100% of which was recompilation)

# %%
function prob_func(prob, i, repeat)
    r = prob.p.r
    v = prob.p.v
    prob.u0[1] = rand(r[1])
    prob.u0[2] = rand(r[2])
    prob.u0[3] = rand(r[3])
    prob.u0[4] = rand(v[1])
    prob.u0[5] = rand(v[2])
    prob.u0[6] = rand(v[3])
    return prob
end
;

# %%
ensemble_prob = EnsembleProblem(prob, prob_func=prob_func)
@time ensemble_sol = solve(ensemble_prob, EnsembleThreads(); trajectories=n)
;
# Out:
#   0.368735 seconds (2.82 M allocations: 410.921 MiB, 267.50% compilation time: 20% of which was recompilation)

# %%
times = ensemble_sol[1].t
survived = zeros(length(times))

@time for i ∈ eachindex(times)
    for j ∈ eachindex(ensemble_sol)
        survived[i] += is_detectable(ensemble_sol[j].u[i], p.trap)
    end
end
# Out:
#   4.059134 seconds (20.81 M allocations: 3.855 GiB, 26.86% gc time, 0.35% compilation time)

# %%
ensemble_sol[1].t[2]
# Out:
# 1.0e-5

# %%
plot(times, survived ./ n, ylim=(0,1))
vline!([release_start_time, release_end_time])

# %% [markdown]
# ## Scan in-trap temperature to fit to data

# %%
root_path = "X:\\Shared drives\\CaOH Data 2024_2\\Data Folder\\CameraImages\\20240415"

start_file = "1718_40"
end_file = "1735_00"
;

# %%
using MAT

# %%
files = readdir(root_path)
files = files[start_file .< files .< end_file]
;

# %%
all_data = []
for file ∈ files
    file_path = root_path * "\\" * file * "\\AllImages.mat"
    data = matread(file_path)
    push!(all_data, data)
end

# get the parameters
all_parameters = [data["parameter_values"][1] for data ∈ all_data]
unique_params = sort(unique(all_parameters))
param_to_idx = Dict(unique_params[i] => i for i ∈ eachindex(unique_params))
n_params = length(unique_params)
;

# %%
x_center = 10
y_center = 10
roi = 5

x_roi = (x_center - roi):(x_center + roi)
y_roi = (y_center - roi):(y_center + roi)

img1_summed = zeros(n_params, 2roi+1, 2roi+1)
img2_summed = zeros(n_params, 2roi+1, 2roi+1)
img1_bg_summed = zeros(n_params, 2roi+1, 2roi+1)
img2_bg_summed = zeros(n_params, 2roi+1, 2roi+1)

n_datapts = zeros(n_params)

for data ∈ all_data
    image_data = data["AllImages"]
    parameter = data["parameter_values"][1]
    parameter_idx = param_to_idx[parameter]
    
    img1 = sum(image_data[x_roi,y_roi,:,1], dims=3)
    img2 = sum(image_data[x_roi,y_roi,:,2], dims=3)
    img1_bg = sum(image_data[x_roi,y_roi,:,3], dims=3)
    img2_bg = sum(image_data[x_roi,y_roi,:,4], dims=3)

    img1_summed[parameter_idx,:,:] .+= img1
    img2_summed[parameter_idx,:,:] .+= img2
    img1_bg_summed[parameter_idx,:,:] .+= img1_bg
    img2_bg_summed[parameter_idx,:,:] .+= img2_bg
    n_datapts[parameter_idx] += size(image_data, 3)
end

img1_mean = img1_summed ./ n_datapts
img2_mean = img2_summed ./ n_datapts
img1_bg_mean = img1_bg_summed ./ n_datapts
img2_bg_mean = img2_bg_summed ./ n_datapts


img1_sums = sum(img1_mean, dims=(2,3))[:,1,1]
img2_sums = sum(img2_mean, dims=(2,3))[:,1,1]
img1_bg_sums = sum(img1_bg_mean, dims=(2,3))[:,1,1]
img2_bg_sums = sum(img2_bg_mean, dims=(2,3))[:,1,1]
;

# %%
function survival_func(img1_sum, img2_sum, img1_bg_sum, img2_bg_sum)
    return (img2_sum - img2_bg_sum) / (img1_sum - img1_bg_sum)
end
;

# %%
data_xs = unique_params .* 1e-6
data_ys = survival_func.(img1_sums, img2_sums, img1_bg_sums, img2_bg_sums)
;

# %%
scatter(data_xs, data_ys)

# %%
ensemble_sol[1].u[end]
# Out:
# 6-element Vector{Float64}:
#  -0.00017537354342362008
#  -0.001009743509764317
#  -0.0003966101795704205
#  -0.022314093374789186
#  -0.1676482668950387
#  -0.05227592913247798

# %%
T = @with_unit 125 "μK"
r, v, a = make_distributions(T, trap)
p = @params (trap, release_start_time, release_end_time, r, v, a)
;

# %%
# Create a release-recapture plot for a single temperature
release_durations = data_xs
surviving_fractions = zeros(length(release_durations))

for (i, release_duration) ∈ enumerate(release_durations)

    # Reset parameters for current run
    p.release_start_time = release_start_time
    p.release_end_time = release_start_time + release_duration

    prob = ODEProblem(update!, u0, tspan, p, save_on=false)
    ensemble_prob = EnsembleProblem(prob, prob_func=prob_func)
    @time ensemble_sol = solve(ensemble_prob, DP5(), EnsembleSplitThreads(); trajectories=n)

    surviving_fractions[i] = mean(is_detectable(sol.u[end], p.trap) for sol ∈ ensemble_sol)
end
# Out:
#   0.439787 seconds (407.58 k allocations: 39.575 MiB, 154.51% compilation time: 39% of which was recompilation)
#   0.179592 seconds (264.39 k allocations: 29.559 MiB)
#   0.165382 seconds (264.27 k allocations: 29.549 MiB)
#   0.146069 seconds (264.27 k allocations: 29.549 MiB)
#   0.117567 seconds (264.27 k allocations: 29.549 MiB)
#   0.092500 seconds (264.28 k allocations: 29.549 MiB)
#   0.069696 seconds (264.27 k allocations: 29.549 MiB)
#   0.057006 seconds (264.16 k allocations: 29.539 MiB)
#   0.045831 seconds (264.27 k allocations: 29.549 MiB)
#   0.034973 seconds (264.16 k allocations: 29.539 MiB)
#   0.034992 seconds (264.15 k allocations: 29.539 MiB)
#   0.030117 seconds (264.27 k allocations: 29.550 MiB)

# %%
plot(release_durations .* 1e6, 0.4 * surviving_fractions,
    title="Release-recapture",
    linewidth=3,
    box=:on,
    label="Monte Carlo simulation",
    xlabel="Release duration (μs)",
    ylabel="Fraction remaining"
)
scatter!(data_xs  .* 1e6, data_ys, label="Data")

# %%
ηs = 15:45
Ts = T_depth ./ ηs

release_durations = data_xs
surviving_fractions = Vector{Float64}[]

iter = Ts
for (i, T) ∈ enumerate(Ts)
    display(ηs[i])
    r, v, a = make_distributions(T, trap)
    p = @params (trap, release_start_time, release_end_time, r, v, a)
    surviving_fraction = zeros(length(release_durations))

    for (j, release_duration) ∈ enumerate(release_durations)

        # Reset parameters for current run
        p.release_start_time = release_start_time
        p.release_end_time = release_start_time + release_duration
    
        prob = ODEProblem(update!, u0, tspan, p, save_on=false)
        ensemble_prob = EnsembleProblem(prob, prob_func=prob_func)
        @time ensemble_sol = solve(ensemble_prob, DP5(), EnsembleSplitThreads(); trajectories=n)
    
        surviving_fraction[j] = mean(is_detectable(sol.u[end], p.trap) for sol ∈ ensemble_sol)
        
    end
    push!(surviving_fractions, surviving_fraction) 
end
# Out:
# 15
#   0.153129 seconds (264.15 k allocations: 29.539 MiB)
#   0.151717 seconds (264.28 k allocations: 29.549 MiB)
#   0.114766 seconds (264.27 k allocations: 29.549 MiB)
#   0.091031 seconds (264.27 k allocations: 29.549 MiB)
#   0.068159 seconds (264.16 k allocations: 29.539 MiB)
#   0.063678 seconds (264.27 k allocations: 29.549 MiB)
#   0.046852 seconds (264.16 k allocations: 29.539 MiB)
#   0.035197 seconds (264.28 k allocations: 29.549 MiB)
#   0.034560 seconds (264.16 k allocations: 29.539 MiB)
#   0.027795 seconds (264.16 k allocations: 29.539 MiB)
#   0.028488 seconds (264.15 k allocations: 29.538 MiB)
#   0.026556 seconds (264.27 k allocations: 29.550 MiB)
# 16
#   0.164820 seconds (264.15 k allocations: 29.538 MiB)
#   0.149208 seconds (264.27 k allocations: 29.549 MiB)
#   0.132693 seconds (264.27 k allocations: 29.549 MiB)
#   0.094457 seconds (264.28 k allocations: 29.549 MiB)
#   0.075733 seconds (264.28 k allocations: 29.549 MiB)
#   0.062291 seconds (264.16 k allocations: 29.539 MiB)
#   0.045613 seconds (264.27 k allocations: 29.549 MiB)
#   0.036043 seconds (264.15 k allocations: 29.539 MiB)
#   0.031602 seconds (264.15 k allocations: 29.538 MiB)
#   0.025493 seconds (264.28 k allocations: 29.550 MiB)
#   0.028251 seconds (264.15 k allocations: 29.538 MiB)
#   0.028094 seconds (264.15 k allocations: 29.538 MiB)
# 17
#   0.167210 seconds (264.15 k allocations: 29.538 MiB)
#   0.375809 seconds (264.28 k allocations: 29.549 MiB, 57.97% gc time)
#   0.131068 seconds (264.28 k allocations: 29.549 MiB)
#   0.106754 seconds (264.27 k allocations: 29.549 MiB)
#   0.077750 seconds (264.28 k allocations: 29.549 MiB)
#   0.065928 seconds (264.16 k allocations: 29.539 MiB)
#   0.046594 seconds (264.28 k allocations: 29.549 MiB)
#   0.034065 seconds (264.16 k allocations: 29.539 MiB)
#   0.032117 seconds (264.16 k allocations: 29.539 MiB)
#   0.030315 seconds (264.28 k allocations: 29.550 MiB)
#   0.029618 seconds (264.16 k allocations: 29.539 MiB)
#   0.023303 seconds (264.15 k allocations: 29.539 MiB)
# 18
#   0.168430 seconds (264.15 k allocations: 29.538 MiB)
#   0.160750 seconds (264.27 k allocations: 29.549 MiB)
#   0.132652 seconds (264.27 k allocations: 29.549 MiB)
#   0.103272 seconds (264.28 k allocations: 29.549 MiB)
#   0.082234 seconds (264.27 k allocations: 29.549 MiB)
#   0.064352 seconds (264.16 k allocations: 29.539 MiB)
#   0.047225 seconds (264.28 k allocations: 29.549 MiB)
#   0.042873 seconds (264.15 k allocations: 29.539 MiB)
#   0.035177 seconds (264.28 k allocations: 29.549 MiB)
#   0.031112 seconds (264.16 k allocations: 29.539 MiB)
#   0.030595 seconds (264.15 k allocations: 29.538 MiB)
#   0.025428 seconds (264.15 k allocations: 29.539 MiB)
# 19
#   0.170197 seconds (264.15 k allocations: 29.538 MiB)
#   0.159213 seconds (264.28 k allocations: 29.549 MiB)
#   0.137139 seconds (264.27 k allocations: 29.549 MiB)
#   0.109344 seconds (264.27 k allocations: 29.549 MiB)
#   0.085074 seconds (264.28 k allocations: 29.549 MiB)
#   0.064616 seconds (264.16 k allocations: 29.539 MiB)
#   0.058134 seconds (264.27 k allocations: 29.549 MiB)
#   0.047137 seconds (264.15 k allocations: 29.539 MiB)
#   0.033642 seconds (264.27 k allocations: 29.549 MiB)
#   0.034442 seconds (264.16 k allocations: 29.539 MiB)
#   0.030535 seconds (264.15 k allocations: 29.538 MiB)
#   0.026891 seconds (264.15 k allocations: 29.539 MiB)
# 20
#   0.173094 seconds (264.15 k allocations: 29.539 MiB)
#   0.165130 seconds (264.28 k allocations: 29.549 MiB)
#   0.159009 seconds (264.27 k allocations: 29.549 MiB)
#   0.125129 seconds (264.28 k allocations: 29.549 MiB)
#   0.095222 seconds (264.27 k allocations: 29.549 MiB)
#   0.073098 seconds (264.28 k allocations: 29.549 MiB)
#   0.048511 seconds (264.15 k allocations: 29.539 MiB)
#   0.040525 seconds (264.15 k allocations: 29.539 MiB)
#   0.037631 seconds (264.27 k allocations: 29.550 MiB)
#   0.032842 seconds (264.15 k allocations: 29.539 MiB)
#   0.030624 seconds (264.16 k allocations: 29.539 MiB)
#   0.027400 seconds (264.27 k allocations: 29.550 MiB)
# 21
#   0.180557 seconds (264.15 k allocations: 29.538 MiB)
#   0.173605 seconds (264.27 k allocations: 29.549 MiB)
#   0.164901 seconds (264.27 k allocations: 29.549 MiB)
#   0.355223 seconds (264.28 k allocations: 29.549 MiB, 69.25% gc time)
#   0.093631 seconds (264.28 k allocations: 29.549 MiB)
#   0.071007 seconds (264.16 k allocations: 29.539 MiB)
#   0.056450 seconds (264.28 k allocations: 29.549 MiB)
#   0.038590 seconds (264.16 k allocations: 29.539 MiB)
#   0.032146 seconds (264.15 k allocations: 29.539 MiB)
#   0.029741 seconds (264.28 k allocations: 29.550 MiB)
#   0.031854 seconds (264.15 k allocations: 29.539 MiB)
#   0.027865 seconds (264.16 k allocations: 29.539 MiB)
# 22
#   0.181558 seconds (264.15 k allocations: 29.538 MiB)
#   0.167945 seconds (264.28 k allocations: 29.549 MiB)
#   0.151054 seconds (264.27 k allocations: 29.549 MiB)
#   0.122054 seconds (264.28 k allocations: 29.549 MiB)
#   0.099100 seconds (264.28 k allocations: 29.549 MiB)
#   0.071109 seconds (264.27 k allocations: 29.549 MiB)
#   0.060232 seconds (264.16 k allocations: 29.539 MiB)
#   0.048072 seconds (264.27 k allocations: 29.549 MiB)
#   0.037901 seconds (264.15 k allocations: 29.539 MiB)
#   0.034906 seconds (264.15 k allocations: 29.538 MiB)
#   0.029720 seconds (264.27 k allocations: 29.550 MiB)
#   0.035631 seconds (264.16 k allocations: 29.539 MiB)
# 23
#   0.172087 seconds (264.15 k allocations: 29.539 MiB)
#   0.160448 seconds (264.27 k allocations: 29.549 MiB)
#   0.147772 seconds (264.28 k allocations: 29.549 MiB)
#   0.118120 seconds (264.27 k allocations: 29.549 MiB)
#   0.097557 seconds (264.28 k allocations: 29.549 MiB)
#   0.073936 seconds (264.28 k allocations: 29.549 MiB)
#   0.050483 seconds (264.15 k allocations: 29.539 MiB)
#   0.048513 seconds (264.27 k allocations: 29.549 MiB)
#   0.037743 seconds (264.15 k allocations: 29.539 MiB)
#   0.035860 seconds (264.15 k allocations: 29.538 MiB)
#   0.030782 seconds (264.27 k allocations: 29.550 MiB)
#   0.028451 seconds (264.15 k allocations: 29.539 MiB)
# 24
#   0.179142 seconds (264.15 k allocations: 29.538 MiB)
#   0.176248 seconds (264.28 k allocations: 29.549 MiB)
#   0.151040 seconds (264.28 k allocations: 29.549 MiB)
#   0.129681 seconds (264.27 k allocations: 29.549 MiB)
#   0.098955 seconds (264.28 k allocations: 29.549 MiB)
#   0.077221 seconds (264.28 k allocations: 29.549 MiB)
#   0.058390 seconds (264.15 k allocations: 29.539 MiB)
#   0.047546 seconds (264.27 k allocations: 29.549 MiB)
#   0.047092 seconds (264.15 k allocations: 29.538 MiB)
#   0.034660 seconds (264.16 k allocations: 29.539 MiB)
#   0.036583 seconds (264.27 k allocations: 29.550 MiB)
#   0.025009 seconds (264.16 k allocations: 29.539 MiB)
# 25
#   0.171276 seconds (264.15 k allocations: 29.538 MiB)
#   0.168744 seconds (264.27 k allocations: 29.549 MiB)
#   0.153392 seconds (264.27 k allocations: 29.549 MiB)
#   0.140414 seconds (264.28 k allocations: 29.549 MiB)
#   0.338716 seconds (264.28 k allocations: 29.549 MiB, 69.26% gc time)
#   0.080146 seconds (264.16 k allocations: 29.539 MiB)
#   0.058893 seconds (264.28 k allocations: 29.549 MiB)
#   0.049185 seconds (264.16 k allocations: 29.539 MiB)
#   0.044411 seconds (264.27 k allocations: 29.549 MiB)
#   0.035306 seconds (264.16 k allocations: 29.539 MiB)
#   0.031448 seconds (264.15 k allocations: 29.538 MiB)
#   0.026224 seconds (264.28 k allocations: 29.550 MiB)
# 26
#   0.174932 seconds (264.15 k allocations: 29.539 MiB)
#   0.171514 seconds (264.28 k allocations: 29.549 MiB)
#   0.154856 seconds (264.28 k allocations: 29.549 MiB)
#   0.129703 seconds (264.27 k allocations: 29.549 MiB)
#   0.110004 seconds (264.27 k allocations: 29.549 MiB)
#   0.084265 seconds (264.28 k allocations: 29.549 MiB)
#   0.051236 seconds (264.16 k allocations: 29.539 MiB)
#   0.044844 seconds (264.27 k allocations: 29.549 MiB)
#   0.045481 seconds (264.15 k allocations: 29.539 MiB)
#   0.034917 seconds (264.16 k allocations: 29.539 MiB)
#   0.036509 seconds (264.28 k allocations: 29.550 MiB)
#   0.026356 seconds (264.15 k allocations: 29.539 MiB)
# 27
#   0.179308 seconds (264.15 k allocations: 29.538 MiB)
#   0.162528 seconds (264.27 k allocations: 29.549 MiB)
#   0.150857 seconds (264.28 k allocations: 29.549 MiB)
#   0.132728 seconds (264.28 k allocations: 29.549 MiB)
#   0.104602 seconds (264.27 k allocations: 29.549 MiB)
#   0.077597 seconds (264.27 k allocations: 29.549 MiB)
#   0.060790 seconds (264.16 k allocations: 29.539 MiB)
#   0.041945 seconds (264.27 k allocations: 29.549 MiB)
#   0.040097 seconds (264.16 k allocations: 29.539 MiB)
#   0.037485 seconds (264.15 k allocations: 29.538 MiB)
#   0.033257 seconds (264.27 k allocations: 29.550 MiB)
#   0.027381 seconds (264.16 k allocations: 29.539 MiB)
# 28
#   0.170287 seconds (264.15 k allocations: 29.538 MiB)
#   0.175420 seconds (264.28 k allocations: 29.549 MiB)
#   0.161172 seconds (264.27 k allocations: 29.549 MiB)
#   0.130397 seconds (264.27 k allocations: 29.549 MiB)
#   0.109564 seconds (264.28 k allocations: 29.549 MiB)
#   0.082131 seconds (264.28 k allocations: 29.549 MiB)
#   0.065705 seconds (264.16 k allocations: 29.539 MiB)
#   0.047120 seconds (264.27 k allocations: 29.549 MiB)
#   0.046385 seconds (264.16 k allocations: 29.539 MiB)
#   0.039793 seconds (264.27 k allocations: 29.549 MiB)
#   0.031675 seconds (264.15 k allocations: 29.538 MiB)
#   0.030942 seconds (264.15 k allocations: 29.539 MiB)
# 29
#   0.167906 seconds (264.15 k allocations: 29.539 MiB)
#   0.182555 seconds (264.27 k allocations: 29.549 MiB)
#   0.166000 seconds (264.28 k allocations: 29.549 MiB)
#   0.135638 seconds (264.28 k allocations: 29.549 MiB)
#   0.108532 seconds (264.28 k allocations: 29.549 MiB)
#   0.093473 seconds (264.28 k allocations: 29.549 MiB)
#   0.294247 seconds (264.28 k allocations: 29.549 MiB, 77.36% gc time)
#   0.045892 seconds (264.16 k allocations: 29.539 MiB)
#   0.037828 seconds (264.27 k allocations: 29.549 MiB)
#   0.042225 seconds (264.16 k allocations: 29.539 MiB)
#   0.036267 seconds (264.15 k allocations: 29.539 MiB)
#   0.029608 seconds (264.28 k allocations: 29.550 MiB)
# 30
#   0.174995 seconds (264.15 k allocations: 29.538 MiB)
#   0.190833 seconds (264.27 k allocations: 29.549 MiB)
#   0.162567 seconds (264.28 k allocations: 29.549 MiB)
#   0.149158 seconds (264.28 k allocations: 29.549 MiB)
#   0.117416 seconds (264.27 k allocations: 29.549 MiB)
#   0.085186 seconds (264.27 k allocations: 29.549 MiB)
#   0.072991 seconds (264.27 k allocations: 29.549 MiB)
#   0.048937 seconds (264.16 k allocations: 29.539 MiB)
#   0.040736 seconds (264.15 k allocations: 29.538 MiB)
#   0.045478 seconds (264.27 k allocations: 29.550 MiB)
#   0.035346 seconds (264.15 k allocations: 29.539 MiB)
#   0.035903 seconds (264.27 k allocations: 29.549 MiB)
# 31
#   0.180432 seconds (264.15 k allocations: 29.538 MiB)
#   0.179559 seconds (264.28 k allocations: 29.549 MiB)
#   0.175916 seconds (264.28 k allocations: 29.549 MiB)
#   0.153077 seconds (264.28 k allocations: 29.549 MiB)
#   0.110746 seconds (264.28 k allocations: 29.549 MiB)
#   0.105285 seconds (264.27 k allocations: 29.549 MiB)
#   0.071761 seconds (264.28 k allocations: 29.549 MiB)
#   0.053971 seconds (264.16 k allocations: 29.539 MiB)
#   0.041769 seconds (264.27 k allocations: 29.549 MiB)
#   0.037809 seconds (264.16 k allocations: 29.539 MiB)
#   0.033946 seconds (264.15 k allocations: 29.538 MiB)
#   0.031192 seconds (264.28 k allocations: 29.550 MiB)
# 32
#   0.191138 seconds (264.15 k allocations: 29.538 MiB)
#   0.181813 seconds (264.28 k allocations: 29.549 MiB)
#   0.164341 seconds (264.27 k allocations: 29.549 MiB)
#   0.140627 seconds (264.27 k allocations: 29.549 MiB)
#   0.125828 seconds (264.27 k allocations: 29.549 MiB)
#   0.102356 seconds (264.28 k allocations: 29.549 MiB)
#   0.072570 seconds (264.27 k allocations: 29.549 MiB)
#   0.047970 seconds (264.15 k allocations: 29.538 MiB)
#   0.041392 seconds (264.15 k allocations: 29.539 MiB)
#   0.038370 seconds (264.27 k allocations: 29.550 MiB)
#   0.033633 seconds (264.15 k allocations: 29.538 MiB)
#   0.028574 seconds (264.27 k allocations: 29.549 MiB)
# 33
#   0.163996 seconds (264.15 k allocations: 29.538 MiB)
#   0.184508 seconds (264.28 k allocations: 29.549 MiB)
#   0.163751 seconds (264.28 k allocations: 29.549 MiB)
#   0.146562 seconds (264.27 k allocations: 29.549 MiB)
#   0.126319 seconds (264.27 k allocations: 29.549 MiB)
#   0.100359 seconds (264.27 k allocations: 29.549 MiB)
#   0.074195 seconds (264.28 k allocations: 29.549 MiB)
#   0.262096 seconds (264.16 k allocations: 29.539 MiB, 78.39% gc time)
#   0.047769 seconds (264.16 k allocations: 29.539 MiB)
#   0.038623 seconds (264.15 k allocations: 29.539 MiB)
#   0.037749 seconds (264.28 k allocations: 29.550 MiB)
#   0.031159 seconds (264.15 k allocations: 29.539 MiB)
# 34
#   0.174952 seconds (264.15 k allocations: 29.538 MiB)
#   0.183229 seconds (264.27 k allocations: 29.549 MiB)
#   0.168033 seconds (264.27 k allocations: 29.549 MiB)
#   0.144176 seconds (264.28 k allocations: 29.549 MiB)
#   0.119372 seconds (264.27 k allocations: 29.549 MiB)
#   0.093116 seconds (264.27 k allocations: 29.549 MiB)
#   0.066837 seconds (264.16 k allocations: 29.539 MiB)
#   0.056484 seconds (264.27 k allocations: 29.549 MiB)
#   0.053529 seconds (264.15 k allocations: 29.539 MiB)
#   0.039495 seconds (264.27 k allocations: 29.549 MiB)
#   0.034134 seconds (264.16 k allocations: 29.539 MiB)
#   0.032213 seconds (264.15 k allocations: 29.539 MiB)
# 35
#   0.175841 seconds (264.15 k allocations: 29.539 MiB)
#   0.182601 seconds (264.27 k allocations: 29.549 MiB)
#   0.172865 seconds (264.27 k allocations: 29.549 MiB)
#   0.135638 seconds (264.27 k allocations: 29.549 MiB)
#   0.120051 seconds (264.27 k allocations: 29.549 MiB)
#   0.096817 seconds (264.28 k allocations: 29.549 MiB)
#   0.063750 seconds (264.28 k allocations: 29.549 MiB)
#   0.055967 seconds (264.16 k allocations: 29.539 MiB)
#   0.045799 seconds (264.27 k allocations: 29.549 MiB)
#   0.038031 seconds (264.15 k allocations: 29.539 MiB)
#   0.039249 seconds (264.15 k allocations: 29.539 MiB)
#   0.029503 seconds (264.27 k allocations: 29.550 MiB)
# 36
#   0.184224 seconds (264.15 k allocations: 29.539 MiB)
#   0.178520 seconds (264.27 k allocations: 29.549 MiB)
#   0.182750 seconds (264.27 k allocations: 29.549 MiB)
#   0.154225 seconds (264.27 k allocations: 29.549 MiB)
#   0.126751 seconds (264.28 k allocations: 29.549 MiB)
#   0.103542 seconds (264.28 k allocations: 29.549 MiB)
#   0.076858 seconds (264.27 k allocations: 29.549 MiB)
#   0.054771 seconds (264.15 k allocations: 29.539 MiB)
#   0.049292 seconds (264.28 k allocations: 29.549 MiB)
#   0.043141 seconds (264.15 k allocations: 29.539 MiB)
#   0.033686 seconds (264.15 k allocations: 29.538 MiB)
#   0.034054 seconds (264.28 k allocations: 29.550 MiB)
# 37
#   0.193498 seconds (264.15 k allocations: 29.538 MiB)
#   0.177410 seconds (264.27 k allocations: 29.549 MiB)
#   0.179946 seconds (264.27 k allocations: 29.549 MiB)
#   0.158191 seconds (264.28 k allocations: 29.549 MiB)
#   0.125906 seconds (264.27 k allocations: 29.549 MiB)
#   0.098150 seconds (264.27 k allocations: 29.549 MiB)
#   0.079927 seconds (264.27 k allocations: 29.549 MiB)
#   0.058491 seconds (264.16 k allocations: 29.539 MiB)
#   0.044178 seconds (264.27 k allocations: 29.549 MiB)
#   0.249780 seconds (264.28 k allocations: 29.549 MiB, 82.88% gc time)
#   0.038009 seconds (264.15 k allocations: 29.538 MiB)
#   0.030589 seconds (264.15 k allocations: 29.539 MiB)
# 38
#   0.179497 seconds (264.15 k allocations: 29.538 MiB)
#   0.185418 seconds (264.27 k allocations: 29.549 MiB)
#   0.178813 seconds (264.28 k allocations: 29.549 MiB)
#   0.158430 seconds (264.27 k allocations: 29.549 MiB)
#   0.120089 seconds (264.28 k allocations: 29.549 MiB)
#   0.105186 seconds (264.27 k allocations: 29.549 MiB)
#   0.076508 seconds (264.28 k allocations: 29.549 MiB)
#   0.061999 seconds (264.15 k allocations: 29.539 MiB)
#   0.051952 seconds (264.27 k allocations: 29.549 MiB)
#   0.046247 seconds (264.15 k allocations: 29.539 MiB)
#   0.038811 seconds (264.15 k allocations: 29.539 MiB)
#   0.031104 seconds (264.27 k allocations: 29.550 MiB)
# 39
#   0.174645 seconds (264.15 k allocations: 29.538 MiB)
#   0.181778 seconds (264.28 k allocations: 29.549 MiB)
#   0.176596 seconds (264.27 k allocations: 29.549 MiB)
#   0.157676 seconds (264.28 k allocations: 29.549 MiB)
#   0.137628 seconds (264.27 k allocations: 29.549 MiB)
#   0.112345 seconds (264.27 k allocations: 29.549 MiB)
#   0.070951 seconds (264.28 k allocations: 29.549 MiB)
#   0.058658 seconds (264.15 k allocations: 29.539 MiB)
#   0.048606 seconds (264.28 k allocations: 29.549 MiB)
#   0.049013 seconds (264.15 k allocations: 29.539 MiB)
#   0.043344 seconds (264.28 k allocations: 29.549 MiB)
#   0.033230 seconds (264.15 k allocations: 29.539 MiB)
# 40
#   0.183424 seconds (264.15 k allocations: 29.539 MiB)
#   0.192175 seconds (264.28 k allocations: 29.549 MiB)
#   0.178847 seconds (264.28 k allocations: 29.549 MiB)
#   0.162268 seconds (264.28 k allocations: 29.549 MiB)
#   0.127955 seconds (264.27 k allocations: 29.549 MiB)
#   0.097043 seconds (264.27 k allocations: 29.549 MiB)
#   0.082655 seconds (264.27 k allocations: 29.549 MiB)
#   0.055269 seconds (264.16 k allocations: 29.539 MiB)
#   0.047794 seconds (264.28 k allocations: 29.549 MiB)
#   0.040163 seconds (264.16 k allocations: 29.539 MiB)
#   0.034254 seconds (264.16 k allocations: 29.539 MiB)
#   0.036248 seconds (264.28 k allocations: 29.550 MiB)
# 41
#   0.180695 seconds (264.15 k allocations: 29.538 MiB)
#   0.183690 seconds (264.27 k allocations: 29.549 MiB)
#   0.180957 seconds (264.27 k allocations: 29.549 MiB)
#   0.163355 seconds (264.27 k allocations: 29.549 MiB)
#   0.138101 seconds (264.27 k allocations: 29.549 MiB)
#   0.102620 seconds (264.27 k allocations: 29.549 MiB)
#   0.076085 seconds (264.28 k allocations: 29.549 MiB)
#   0.060486 seconds (264.16 k allocations: 29.539 MiB)
#   0.046229 seconds (264.27 k allocations: 29.549 MiB)
#   0.045581 seconds (264.16 k allocations: 29.539 MiB)
#   0.261548 seconds (264.28 k allocations: 29.549 MiB, 83.64% gc time)
#   0.030679 seconds (264.15 k allocations: 29.538 MiB)
# 42
#   0.181518 seconds (264.15 k allocations: 29.538 MiB)
#   0.186269 seconds (264.28 k allocations: 29.549 MiB)
#   0.176348 seconds (264.27 k allocations: 29.549 MiB)
#   0.148791 seconds (264.27 k allocations: 29.549 MiB)
#   0.139020 seconds (264.27 k allocations: 29.549 MiB)
#   0.107386 seconds (264.27 k allocations: 29.549 MiB)
#   0.080260 seconds (264.27 k allocations: 29.549 MiB)
#   0.063124 seconds (264.15 k allocations: 29.539 MiB)
#   0.048689 seconds (264.27 k allocations: 29.549 MiB)
#   0.039670 seconds (264.16 k allocations: 29.539 MiB)
#   0.040283 seconds (264.27 k allocations: 29.549 MiB)
#   0.035428 seconds (264.16 k allocations: 29.539 MiB)
# 43
#   0.176461 seconds (264.15 k allocations: 29.538 MiB)
#   0.183900 seconds (264.28 k allocations: 29.549 MiB)
#   0.178225 seconds (264.28 k allocations: 29.549 MiB)
#   0.159869 seconds (264.28 k allocations: 29.549 MiB)
#   0.146983 seconds (264.28 k allocations: 29.549 MiB)
#   0.111671 seconds (264.28 k allocations: 29.549 MiB)
#   0.076928 seconds (264.28 k allocations: 29.549 MiB)
#   0.063701 seconds (264.16 k allocations: 29.539 MiB)
#   0.056082 seconds (264.27 k allocations: 29.549 MiB)
#   0.049653 seconds (264.16 k allocations: 29.539 MiB)
#   0.036351 seconds (264.27 k allocations: 29.549 MiB)
#   0.036493 seconds (264.15 k allocations: 29.539 MiB)
# 44
#   0.178029 seconds (264.15 k allocations: 29.538 MiB)
#   0.181928 seconds (264.27 k allocations: 29.549 MiB)
#   0.181523 seconds (264.27 k allocations: 29.549 MiB)
#   0.158450 seconds (264.27 k allocations: 29.549 MiB)
#   0.138150 seconds (264.27 k allocations: 29.549 MiB)
#   0.110058 seconds (264.27 k allocations: 29.549 MiB)
#   0.084322 seconds (264.27 k allocations: 29.549 MiB)
#   0.071178 seconds (264.15 k allocations: 29.539 MiB)
#   0.056208 seconds (264.27 k allocations: 29.549 MiB)
#   0.045453 seconds (264.15 k allocations: 29.539 MiB)
#   0.040573 seconds (264.27 k allocations: 29.549 MiB)
#   0.036181 seconds (264.16 k allocations: 29.539 MiB)
# 45
#   0.177266 seconds (264.15 k allocations: 29.538 MiB)
#   0.189748 seconds (264.27 k allocations: 29.549 MiB)
#   0.181789 seconds (264.28 k allocations: 29.549 MiB)
#   0.160068 seconds (264.28 k allocations: 29.549 MiB)
#   0.144013 seconds (264.28 k allocations: 29.549 MiB)
#   0.118979 seconds (264.27 k allocations: 29.549 MiB)
#   0.088780 seconds (264.28 k allocations: 29.549 MiB)
#   0.066532 seconds (264.15 k allocations: 29.539 MiB)
#   0.062125 seconds (264.27 k allocations: 29.549 MiB)
#   0.042930 seconds (264.27 k allocations: 29.549 MiB)
#   0.042397 seconds (264.15 k allocations: 29.539 MiB)
#   0.028581 seconds (264.16 k allocations: 29.539 MiB)

# %%
χ²(data, preds) = sum((data .- preds).^2 ./ 0.04^2);

# %%
function model_with_best_scaling(data_ys, model_ys)
    min_error = Inf
    best_scaling = 1.0 
    for scaling ∈ 0.1:0.01:5.0
        error = χ²(data_ys, model_ys .* scaling)
        if error < min_error
            min_error = error
            best_scaling = scaling
        end
    end
    println(best_scaling)
    return model_ys .* best_scaling
end
# Out:
# model_with_best_scaling (generic function with 1 method)

# %%
χ²_errors = [
    χ²(
        data_ys,
        model_with_best_scaling(data_ys, surviving_fractions[i])
        )
    for i ∈ 1:size(surviving_fractions, 1)]
;
# Out:
# 0.48
# 0.47
# 0.46
# 0.45
# 0.44
# 0.43
# 0.42
# 0.41
# 0.41
# 0.4
# 0.4
# 0.39
# 0.39
# 0.39
# 0.38
# 0.38
# 0.37
# 0.37
# 0.37
# 0.37
# 0.37
# 0.36
# 0.36
# 0.36
# 0.36
# 0.35
# 0.35
# 0.35
# 0.35
# 0.34
# 0.34

# %%
plot(T_depth ./ Ts, χ²_errors,
    linewidth=3,
    )

# %%
min_error, best_idx = findmin(χ²_errors)
Ts[best_idx] |> display
best_preds = model_with_best_scaling(data_ys, surviving_fractions[best_idx])

plot(release_durations .* 1e6, best_preds,
    title="",
    linewidth=3,
    box=:on,
    label="Monte Carlo simulation",
    xlabel="Release duration (μs)",
    ylabel="Fraction remaining"
)
scatter!(data_xs  .* 1e6, data_ys, label="Data")
# Out:
# 0.00014482758620689654
# 0.38

# %%
using LsqFit
@. model(T, p) = p[1] * (T - p[2])^2 + p[3]
# Out:
# model (generic function with 1 method)

# %%
x = 0
y = 0

lb = [0, 0.0, 0.]
p0 = [0., 8, 0.]
ub = [1.0, 40, 35.0]
fitted_model = curve_fit(model, ηs[x+1:end-y], χ²_errors[x+1:end-y], p0, lower=lb, upper=ub)
display(fitted_model.param)
plot(ηs[x+1:end-y], χ²_errors[x+1:end-y], label="Monte Carlo", xlabel="η", ylabel="χ² error")
plot!(ηs[x+1:end-y], model(ηs[x+1:end-y], fitted_model.param), label="Parabola")
# Out:
# 3-element Vector{Float64}:
#   0.017918026432111364
#  30.710157588522566
#   6.523201782264554

# %%
# The second derivative with respect to T is given by
best_η = fitted_model.param[2]
η_error = sqrt(2 * (2fitted_model.param[3])^(-1))
best_T = 1e6 * T_depth / fitted_model.param[2]
T_error = best_T * (η_error / best_η)
;

# %%
println("Best T fit: ", round(best_T, digits=2), "(", round(T_error, digits=0), ")")
# Out:
# Best T fit: 136.76(2.0)

# %% [markdown]
# ### Bootstrap model outputs to get an error range

# %%
surviving_fractions

# %%
n = 2_000
T = 60e-6
r, v, a = make_distributions(T)

simul_xs = collect(shaved_U_depth_ratios[1]:0.01:shaved_U_depth_ratios[end])

detectable_all = zeros(n, length(simul_xs))

for (j, shaved_U_depth_ratio) ∈ enumerate(simul_xs)
    shaved_U_depth = original_U_depth * shaved_U_depth_ratio

    # Reset parameters for current run
    p.time = 0.0
    p.shaved_U_depth = shaved_U_depth

    particles = StructArray{Particle}(undef, n)
    detectable = zeros(Bool, n)
    trajectories = [SVector{3, Float64}[] for _ ∈ 1:length(particles)]
    s = @params (detectable, trajectories)

    @time propagate_particles!(r, v, a, alg, particles, f, save, discard, save_every, delete_every, max_steps, update, p, s, dt, use_adaptive, 
        dt_min, dt_max, abstol, true)

    detectable_all[:,j] .= s.detectable
    
end
# Out:
# WARNING: redefinition of constant T. This may fail, cause incorrect answers, or produce other errors.
# MethodError: no method matching make_distributions(::Float64)
#
# Closest candidates are:
#   make_distributions(::Any, ::AsymmetricGaussianTrap)
#    @ BeamPropagation C:\Google Drive\github\BeamPropagation\src\AsymmetricGaussianTrap.jl:54
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[24]:3

# %%
n_bootstraps = 10000

surviving_fractions_lower = zeros(length(simul_xs))
surviving_fractions_upper = zeros(length(simul_xs))

for i ∈ eachindex(simul_xs)
    bootstrap_idxs = rand(1:n, n, n_bootstraps)
    bootstrap_samples = detectable_all[:,i][bootstrap_idxs]
    bootstrap_means = vec(mean(bootstrap_samples, dims=1))
    surviving_fractions_lower[i] = percentile(bootstrap_means, 50 - 34.1)
    surviving_fractions_upper[i] = percentile(bootstrap_means, 50 + 34.1)
end
# Out:
# UndefVarError: `simul_xs` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[25]:3

# %%
plot(simul_xs, surviving_fractions_lower, fillrange=surviving_fractions_upper, legend=nothing)
# Out:
# UndefVarError: `surviving_fractions_upper` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[26]:1

# %%
simul_vals = vec(mean(detectable_all, dims=1));
# Out:
# UndefVarError: `detectable_all` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[27]:1

# %%
simul_vals
# Out:
# UndefVarError: `simul_vals` not defined

# %% [markdown]
# ### Bootstrapping data

# %%
using Distributions

# %%
data_sampler(μs, ϵs) = [Normal(μs[i], ϵs[i]) for i ∈ eachindex(μs)]
ds = data_sampler(data_ys, data_ys_errors)
;
# Out:
# UndefVarError: `data_ys_errors` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[30]:2

# %%
n_bootstraps = 100_000
min_Ts = zeros(n_bootstraps)

for i ∈ 1:n_bootstraps
    bootstrap_sample = rand.(ds)
    squared_errors = vec(sum((bootstrap_sample .- surviving_fractions').^2 ./ length(data_ys), dims=1))
    _, best_idx = findmin(squared_errors)
    min_Ts[i] = Ts[best_idx]
end
histogram(min_Ts, bins=Ts)
# Out:
# UndefVarError: `ds` not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ .\In[31]:5

# %%
mean(min_Ts)
# Out:
# 0.0

# %%
percentile(min_Ts, 50 - 34.1) |> display
percentile(min_Ts, 50 + 34.1) |> display
# Out:
# 0.0
# 0.0
